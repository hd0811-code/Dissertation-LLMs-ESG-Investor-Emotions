# %% [markdown]
# # Correlation Matrix: FinBERT, DistilRoBERTa, LLM-based emotions and Returns

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel("FinBERT DistilRoBERTa LLM emotion.xlsx")

pd.set_option("display.max_columns", None)
pd.set_option("display.width", 3000)
pd.set_option("display.max_colwidth", None)

# %%
correlation_matrix = df[
    [
        "FinBERT",
        "DistilRoBERTa_fear",
        "DistilRoBERTa_anger",
        "DistilRoBERTa_disgust",
        "DistilRoBERTa_joy",
        "DistilRoBERTa_sadness",
        "DistilRoBERTa_surprise",
        "LLM_fear",
        "LLM_anger",
        "LLM_disgust",
        "LLM_joy",
        "LLM_sadness",
        "LLM_surprise",
        "natural_gas_return_t-1",
        "natural_gas_return_t",
        "oil_return_t-1",
        "oil_return_t",
        "clean_return_t-1",
        "clean_return_t",

    ]
].corr()


print(correlation_matrix.round(3))
# Out:
#                         FinBERT  DistilRoBERTa_fear  DistilRoBERTa_anger  DistilRoBERTa_disgust  DistilRoBERTa_joy  DistilRoBERTa_sadness  DistilRoBERTa_surprise  LLM_fear  LLM_anger  LLM_disgust  LLM_joy  LLM_sadness  LLM_surprise  natural_gas_return_t-1  natural_gas_return_t  oil_return_t-1  oil_return_t  clean_return_t-1  clean_return_t
# FinBERT                   1.000               0.039               -0.281                  0.060              0.442                 -0.174                   0.015    -0.349     -0.280       -0.149    0.277       -0.343        -0.076                  -0.014                -0.005          -0.004         0.172            -0.164           0.062
# ...

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize=(16, 13))
sns.heatmap(
    correlation_matrix,
    annot=True,          
    fmt=".2f",          
    cmap="coolwarm",
    center=0,
    square=True,
    annot_kws={"size": 8}
)

plt.xticks(rotation=90, fontsize=9)
plt.yticks(rotation=0, fontsize=9)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Eigenvector Decomposition

# %%
# Out:
# Reconstruction error (Frobenius norm): 7.314368281682527e-15
# Eigenvalues & Variance Explained
#   λ_1 = 3.3426  |  17.59%  |  cumulative 17.59%
#   λ_2 = 2.0299  |  10.68%  |  cumulative 28.28%
#   λ_3 = 1.7431  |  9.17%  |  cumulative 37.45%
#   λ_4 = 1.6467  |  8.67%  |  cumulative 46.12%
#   λ_5 = 1.4110  |  7.43%  |  cumulative 53.54%
#   λ_6 = 1.1967  |  6.30%  |  cumulative 59.84%
#   λ_7 = 1.0515  |  5.53%  |  cumulative 65.38%
#   λ_8 = 1.0141  |  5.34%  |  cumulative 70.71%
#   λ_9 = 0.8981  |  4.73%  |  cumulative 75.44%
#   λ_10 = 0.8077  |  4.25%  |  cumulative 79.69%
#   λ_11 = 0.7387  |  3.89%  |  cumulative 83.58%
#   λ_12 = 0.6511  |  3.43%  |  cumulative 87.01%
#   λ_13 = 0.5955  |  3.13%  |  cumulative 90.14%
#   λ_14 = 0.4704  |  2.48%  |  cumulative 92.62%
#   λ_15 = 0.4081  |  2.15%  |  cumulative 94.76%
#   λ_16 = 0.3385  |  1.78%  |  cumulative 96.55%
#   λ_17 = 0.2895  |  1.52%  |  cumulative 98.07%
#   λ_18 = 0.1976  |  1.04%  |  cumulative 99.11%
# ...
